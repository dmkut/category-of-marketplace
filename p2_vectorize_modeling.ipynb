# %%
import pandas as pd
import numpy as np
import ast
from pandas import json_normalize

from tqdm.notebook import tqdm
tqdm.pandas()
import warnings
warnings.filterwarnings('ignore')

# %%
# модели
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from lightgbm import LGBMModel
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.dummy import DummyRegressor

# инструменты
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder


from sklearn.metrics import f1_score

from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline

pd.set_option('display.max_colwidth', 30)

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### Загрузка даных

# %%
train = pd.read_csv('~/kazan-exp/train_lemm.csv')

# %%
test = pd.read_csv('~/kazan-exp/test_lemm.csv')

# %%
train.head()
# Out:
#                            title             level_1               level_2  \
# 0  Зарядный кабель Borofone B...         Электроника  Смартфоны и телефоны
# 1                     Трусы Sela              Одежда        Женская одежда
# 2  Гуашь "ЮНЫЙ ВОЛШЕБНИК", 12...  Хобби и творчество             Рисование
# 3  Колба для кальяна Крафт (р...  Хобби и творчество    Товары для курения
# 4  Пижама женская, однотонная...              Одежда        Женская одежда
#
#                  level_3                       level_4           level_5  \
# 0  Аксессуары и запчасти  Зарядные устройства и кабели            Кабели
# 1     Белье и купальники                         Трусы             Трусы
# 2       Краски, пигменты              Краски, пигменты  Краски, пигменты
# 3   Кальяны и аксессуары                         Колбы             Колбы
# 4        Домашняя одежда                        Пижамы            Пижамы
#
#                             lemm  shop_id
# 0  зарядный кабель borofone l...     9031
# 1                     трусы sela    18305
# 2  гуашь юный волшебник цвето...    16357
# 3  колба кальян крафт разный ...    34666
# 4  пижама женский однотонный ...    26389

# %%
test.head()
# Out:
#                            title                           lemm
# 0  Светодиодная лента Smart l...  светодиодный лента smart s...
# 1  Стекло ПЛЕНКА керамик мато...  стекло пленка керамика мат...
# 2  Проводные наушники с микро...  проводной наушник микрофон...
# 3  Декоративная табличка "Пра...  декоративный табличка прав...
# 4  Подставка под ложку керами...  подставка ложка керамическ...

# %% [markdown]
# Заранее подготовим словарь для декодирования целевого признака

# %%
target = pd.concat([train['level_5'], train['shop_id']], axis=1)

# %%
target_keys = target[['level_5', 'shop_id']].drop_duplicates().sort_values('shop_id')

# %%
target_id = dict(target_keys.values)

# %%
id_target = dict(target_keys[['shop_id', 'level_5']].values)

# %%
id_target
# Out:
# {9: 'Подарочные наборы',
#  12: 'Безмены и весы',
#  13: 'Органайзеры и разделители',
#  18: 'Цветы и натюрморты',
#  19: 'Подставки и держатели',
#  25: 'Материалы для рукоделия',
#  36: 'Щетки и губки',
#  37: 'Коннекторы',
#  42: 'Подставки для столовых приборов',
#  43: 'Коврики для мыши',
#  46: 'Мыльницы',
#  51: 'Воздушные шары',
#  54: 'Аксессуары для спецодежды',
#  55: 'Карты памяти',
#  63: 'Микроскопы',
#  64: 'Гольфы и гетры',
#  65: 'Носки и подследники',
#  66: 'Полки для ванной',
#  67: 'Вилки',
#  68: 'Карты памяти',
#  71: 'Бюстгальтеры',
#  78: 'Воздушные шары',
#  79: 'Умные часы',
#  80: 'Ключницы настенные',
#  86: 'Трусы',
#  87: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  89: 'Кабели',
#  93: 'Корректирующее белье',
#  95: 'Римские свечи и фонтаны',
#  98: 'Создание украшений',
#  99: 'Чехлы',
#  100: 'Наборы для покера',
#  103: 'Коробки',
#  104: 'Игровые наушники',
#  106: 'Портативная акустика',
#  107: 'Портативная акустика',
#  110: 'Гирлянды',
#  111: 'Геймпады, джойстики и триггеры',
#  119: 'Защитные стекла',
#  122: 'Худи',
#  123: 'Органайзеры для кабелей',
#  126: 'Штативы',
#  127: 'Сувениры',
#  132: 'Иглы',
#  136: 'Куртки и пуховики',
#  140: 'Гирлянды-растяжки',
#  141: 'Нижнее белье',
#  143: 'Зарядные устройства для ноутбуков',
#  150: 'Мыши',
#  152: 'Батарейки',
#  156: 'Маски карнавальные',
#  157: 'Тряпки, салфетки и губки',
#  175: 'Платья вечерние',
#  180: 'Держатели для кабелей',
#  185: 'Чехлы для игровых приставок',
#  187: 'Носки и подследники',
#  191: 'Сабо',
#  197: 'Чехлы',
#  198: 'Люди',
#  204: 'Беспроводные наушники',
#  205: 'Пакеты и мешочки многоразовые',
#  209: 'Водолазки',
#  232: 'Купальники',
#  233: 'Пижамы',
#  237: 'Сумки хозяйственные',
#  239: 'Шнурки',
#  243: 'Чулки',
#  249: 'Моделирование',
#  260: 'Худи',
#  276: 'Чехлы',
#  298: 'Домашние платья и туники',
#  308: 'Кабели',
#  310: 'Оригами',
#  316: 'Диспенсеры, дозаторы',
#  329: 'Запчасти для смартфонов',
#  339: 'Кабели',
#  346: 'Спортивные шорты',
#  355: 'Стекла',
#  356: 'Кружки',
#  361: 'Гирлянды',
#  362: 'Открытки',
#  371: 'Коврики для намаза',
#  372: 'Фитнес браслеты',
#  377: 'Декоративные ленты',
#  384: 'Аксессуары',
#  399: 'Футболки',
#  404: 'Носки и подследники',
#  408: 'Шнурки',
#  412: 'Мешочки подарочные',
#  414: 'Шкатулки',
#  417: 'Автомобильные держатели',
#  423: 'Щетки и губки',
#  433: 'Материалы для рукоделия',
#  435: 'Алмазные мозаики',
#  436: 'Держатели, подставки и подносы',
#  448: 'Коробки, корзины, контейнеры',
#  466: 'Топы',
#  468: 'Люди',
#  469: 'Спицы и крючки',
#  479: 'Мыльницы',
#  492: 'Таблички, номера и крючки',
#  517: 'Рукава и пакеты для запекания',
#  521: 'Банки и крышки',
#  532: 'Лонгсливы',
#  537: 'Кроссовки',
#  538: 'Скалки',
#  540: 'Стикеры',
#  578: 'Подставки для ноутбуков',
#  583: 'Кардиганы',
#  584: 'Автомобильные держатели',
#  596: 'Органайзеры и разделители',
#  598: 'Новогодние сувениры и подарки',
#  602: 'Пульты ДУ',
#  610: 'Кеды',
#  611: 'Чехлы и кейсы',
#  615: 'Чулки',
#  620: 'Стельки и вставки',
#  629: 'Чехлы',
#  630: 'Чехлы',
#  631: 'Плавки',
#  632: 'Инструменты для рукоделия',
#  635: 'Раскраски, наборы для росписи',
#  665: 'Пляжная одежда',
#  668: 'Чехлы',
#  677: 'Внешние аккумуляторы',
#  688: 'Геймпады, джойстики и триггеры',
#  695: 'Запчасти для смартфонов',
#  698: 'Коробки',
#  711: 'Защитные пленки',
#  712: 'Пакеты подарочные',
#  742: 'Планшеты для рисования',
#  746: 'Коврики для ванной',
#  752: 'Мишура, дождик, растяжки',
#  764: 'Майки и топы бельевые',
#  785: 'Носки и подследники',
#  786: 'Термометры, барометры',
#  798: 'Травяные',
#  801: 'Раскраски, наборы для росписи',
#  815: 'Носки и подследники',
#  816: 'Трусы',
#  817: 'Скрапбукинг',
#  818: 'Сетевые зарядные устройства',
#  821: 'Сетки и коврики для раковин',
#  822: 'Декоративные ленты',
#  831: 'Сетки и коврики для раковин',
#  837: 'Шумовки',
#  849: 'Футболки',
#  861: 'Носки и подследники',
#  864: 'Подушки на стул',
#  869: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  874: 'Футболки',
#  875: 'Консервные ножи и открывашки',
#  887: 'Наборы для рисования песком',
#  893: 'Трусы',
#  914: 'Чехлы',
#  916: 'Ролики для чистки одежды',
#  923: 'Пробки',
#  932: 'Брюки',
#  935: 'Елочные игрушки и украшения',
#  946: 'Мешки для мусора',
#  949: 'Награды, кубки, ленты',
#  953: 'Шапочки, чепчики и рукавички',
#  957: 'Гольфы и гетры',
#  960: 'Щетки и сметки',
#  964: 'Комплекты клавиатур и мышей',
#  971: 'Скрапбукинг',
#  972: 'Джемперы',
#  992: 'Футболки',
#  999: 'Измерители стопы',
#  1005: 'Подставки и держатели',
#  1013: 'Чехлы и кейсы',
#  1016: 'Моделирование',
#  1034: 'Легинсы и лосины',
#  1050: 'Кабели и зарядные устройства',
#  1054: 'Футболки',
#  1056: 'Лейки и опрыскиватели',
#  1063: 'Носки и подследники',
#  1066: 'Формы для яичницы',
#  1068: 'Внешние аккумуляторы',
#  1073: 'Чистящие средства',
#  1090: 'Карты памяти',
#  1096: 'Скетчбуки',
#  1105: 'Шкатулки',
#  1115: 'Аксессуары',
#  1123: 'Аксессуары для декора столовых предметов',
#  1129: 'Автомобильные держатели',
#  1141: 'Корректирующее белье',
#  1146: 'Перчатки для сенсорных экранов',
#  1158: 'Телевизоры',
#  1161: 'Аксессуары для наушников',
#  1165: 'Платья',
#  1177: 'Салфетки бумажные',
#  1187: 'Спортивные толстовки',
#  1188: 'Сувениры',
#  1195: 'Брюки',
#  1208: 'Кабели',
#  1215: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  1219: 'Полотенца',
#  1226: 'Конверты',
#  1230: 'Коробки',
#  1232: 'Аксессуары',
#  1233: 'Умные часы',
#  1243: 'Изготовление игрушек',
#  1246: 'Домашняя обувь',
#  1262: 'Анатомические подушки',
#  1268: 'Чехлы',
#  1271: 'Прочие кухонные инструменты',
#  1273: 'Ножницы кухонные',
#  1275: 'Фартуки кухонные',
#  1278: 'Подушки для сна',
#  1281: 'Ползунки и штанишки',
#  1306: 'Автомобильные держатели',
#  1315: 'Bluetooth-брелоки',
#  1325: 'Скатерти и подставки под горячее',
#  1331: 'Чехлы',
#  1333: 'Подушки для сна',
#  1337: 'Комплектующие',
#  1343: 'Стикеры',
#  1346: 'Коробки',
#  1370: 'Коробки',
#  1375: 'Носки и подследники',
#  1385: 'Радиаторы и кулеры',
#  1388: 'Чехлы',
#  1398: 'Бенгальские огни',
#  1410: 'Фотобоксы',
#  1416: 'Сетевые зарядные устройства',
#  1423: 'Охлаждение напитков',
#  1424: 'Носки и подследники',
#  1425: 'Термосы',
#  1430: 'Банки и крышки',
#  1435: 'Термокружки',
#  1437: 'Стикеры',
#  1441: 'Автомобильные держатели',
#  1442: 'Подставки и держатели',
#  1444: 'Наволочки',
#  1449: 'Платья повседневные',
#  1450: 'Трусы',
#  1454: 'Пробки',
#  1469: 'Комплекты',
#  1493: 'Колготки',
#  1516: 'Гирлянды',
#  1538: 'Геймпады, джойстики и триггеры',
#  1543: 'Запчасти для смартфонов',
#  1558: 'Штативы',
#  1562: 'Одежда для поваров и официантов',
#  1569: 'Ботинки',
#  1581: 'Комплекты белья',
#  1592: 'Цветной дым',
#  1599: 'Ножи кухонные',
#  1607: 'Автомобильные держатели',
#  1617: 'Картины',
#  1620: 'Открытки',
#  1621: 'Преобразователи напряжения',
#  1624: 'Футболки',
#  1626: 'Подставки и держатели',
#  1633: 'Амулеты, обереги и талисманы',
#  1636: 'Звуковые карты',
#  1637: 'Адаптеры и переходники',
#  1647: 'Подставки и держатели',
#  1652: 'Носки и подследники',
#  1663: 'Ароматы для дома',
#  1671: 'Органайзеры и разделители',
#  1675: 'Гирлянды',
#  1684: 'Ручки для посуды',
#  1691: 'Носки и подследники',
#  1705: 'Умные часы',
#  1707: 'Настольные игры',
#  1713: 'Аксессуары',
#  1722: 'Комплектующие',
#  1728: 'Коробки, корзины, контейнеры',
#  1741: 'Выжигание, поделки из дерева',
#  1745: 'Платья',
#  1746: 'Проводные наушники',
#  1756: 'Безмены и весы',
#  1760: 'Автомобильные держатели',
#  1763: 'Сушилки для белья',
#  1813: 'Колготки',
#  1817: 'Сумки хозяйственные',
#  1819: 'Чехлы',
#  1822: 'Часы',
#  1835: 'Формы для выпечки',
#  1845: 'Беспроводные наушники',
#  1850: 'Спортивные костюмы',
#  1856: 'Стикеры',
#  1857: 'Полки кухонные',
#  1878: 'Салфетки',
#  1896: 'Кружки',
#  1905: 'Ароматы для дома',
#  1906: 'Прочие аксессуары для вязания',
#  1925: 'Заварочные чайники',
#  1928: 'Декупаж',
#  1931: 'Машинки для удаления катышек',
#  1940: 'Брюки',
#  1957: 'Геймпады, джойстики и триггеры',
#  1965: 'Свечи для торта',
#  1967: 'Аксессуары для глажки',
#  1975: 'Носки, пинетки',
#  1979: 'Микрофоны',
#  1981: 'Домашние платья и туники',
#  1989: 'Прочие аксессуары',
#  2005: 'Картины',
#  2009: 'Шлепанцы и сланцы',
#  2026: 'Свечи',
#  2028: 'Ножи кухонные',
#  2037: 'Сетевые зарядные устройства',
#  2051: 'Носки и подследники',
#  2053: 'Инструменты и принадлежности',
#  2069: 'Кроссовки',
#  2071: 'Пакеты подарочные',
#  2081: 'Шейкеры для напитков',
#  2100: 'Полотенца кухонные',
#  2102: 'Воздушные шары',
#  2103: 'Джинсы',
#  2104: 'Ботинки',
#  2167: 'Пазлы',
#  2177: 'Раскраски, наборы для росписи',
#  2191: 'Футболки',
#  2193: 'Свечи',
#  2195: 'Bluetooth-гарнитуры',
#  2204: 'Крючки и держатели',
#  2207: 'Прочие кухонные инструменты',
#  2208: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  2211: 'Щетки и сметки',
#  2213: 'Трусы',
#  2215: 'Валенки',
#  2223: 'Ремешки',
#  2224: 'Боди',
#  2227: 'Пакеты и мешочки многоразовые',
#  2228: 'Маски карнавальные',
#  2239: 'Фильтры-кувшины',
#  2272: 'Защитные стекла',
#  2273: 'Нитки',
#  2279: 'Создание украшений',
#  2289: 'Мешки, шприцы и насадки',
#  2320: 'Коннекторы',
#  2326: 'Новогодние сувениры и подарки',
#  2352: 'Открытки',
#  2374: 'Защитные стекла',
#  2400: 'Магниты',
#  2405: 'Чашки и блюдца',
#  2406: 'Органайзеры и разделители',
#  2408: 'Наборы для рисования песком',
#  2413: 'Пакеты подарочные',
#  2417: 'Геймпады, джойстики и триггеры',
#  2443: 'Прочие приставки',
#  2457: 'Формы для пельменей',
#  2470: 'Рассеиватели и световые кольца',
#  2475: 'Кабели',
#  2481: 'Футболки и майки домашние',
#  2482: 'Аксессуары для декора столовых предметов',
#  2484: 'Пижамы',
#  2487: 'Комбинезоны повседневные',
#  2489: 'Ситечки для заварки',
#  2491: 'Мусорные ведра и баки',
#  2496: 'Комплекты',
#  2497: 'Мешочки подарочные',
#  2513: 'Другое',
#  2548: 'Открытки',
#  2579: 'Носки и подследники',
#  2581: 'Фрукто-овощечистки',
#  2600: 'Разделочные доски',
#  2602: 'Формы для яичницы',
#  2606: 'Ершики для унитаза',
#  2614: 'Беспроводные наушники',
#  2630: 'Осветители и вспышки',
#  2636: 'Аксессуары',
#  2649: 'Аксессуары для экшн камер',
#  2672: 'Декоративные ленты',
#  2673: 'Футболки',
#  2681: 'Топы',
#  2693: 'Подставки для яиц',
#  2698: 'Формы для выпечки',
#  2707: 'Часы',
#  2708: 'Эпоксидная смола',
#  2714: 'Защитные стекла',
#  2721: 'Коробки',
#  2727: 'Термометры, барометры',
#  2728: 'Носки и подследники',
#  2729: 'Стикеры',
#  2734: 'Комплекты',
#  2741: 'Кабели',
#  2744: 'Защитные стекла',
#  2746: 'Футболки',
#  2747: 'Коробки',
#  2753: 'Вакуумные пакеты',
#  2772: 'Картины',
#  2785: 'Пижамы',
#  2793: 'Материалы для рукоделия',
#  2809: 'Шумовки',
#  2826: 'Чехлы для наушников',
#  2837: 'Кабели и зарядные устройства',
#  2840: 'Нижнее белье',
#  2848: 'Носки, пинетки',
#  2857: 'Автомобильные держатели',
#  2867: 'Боди и комбинезоны',
#  2875: 'Сменные картриджи для фильтров-кувшинов',
#  2880: 'Умные часы',
#  2884: 'Солнцезащитные и статические пленки',
#  2893: 'Ножи кухонные',
#  2926: 'HDMI оборудование',
#  2931: 'Держатели для кабелей',
#  2939: 'Пиджаки',
#  2948: 'Кабели и зарядные устройства',
#  2954: 'Чехлы для обуви',
#  2957: 'Аксессуары',
#  2958: 'Платья повседневные',
#  2959: 'Футболки и лонгсливы',
#  2968: 'Чаши',
#  2973: 'Свечи',
#  2974: 'Тряпки, салфетки и губки',
#  2977: 'Футболки',
#  2985: 'Зарядные устройства для аккумуляторов',
#  2986: 'Майки',
#  2996: 'Салфетницы',
#  3002: 'Чехлы',
#  3008: 'Штативы',
#  3026: 'Аксессуары для наушников',
#  3028: 'Стельки и вставки',
#  3068: 'Планшеты для рисования',
#  3070: 'Щетки и сметки',
#  3079: 'Платья повседневные',
#  3080: 'Чехлы для игровых приставок',
#  3083: 'Держатели для фотооборудования',
#  3092: 'Автомобильные держатели',
#  3107: 'Кружки',
#  3108: 'Кружки',
#  3121: 'Колбы',
#  3129: 'Кроссовки',
#  3131: 'Топы',
#  3149: 'Мыльницы',
#  3169: 'Подставки и держатели',
#  3174: 'Шорты',
#  3177: 'Сетки и коврики для раковин',
#  3186: 'Шорты',
#  3196: 'Умные часы',
#  3226: 'Комплекты',
#  3229: 'Ремешки',
#  3237: 'Сувениры',
#  3240: 'Спортивные легинсы',
#  3250: 'Водолазки',
#  3251: 'Сарафаны',
#  3256: 'Перчатки хозяйственные',
#  3272: 'Антенны и аксессуары',
#  3274: 'Моделирование',
#  3275: 'Магниты',
#  3291: 'Планшеты для рисования',
#  3301: 'Майки',
#  3302: 'Халаты',
#  3313: 'Подсвечники',
#  3329: 'Мыльницы',
#  3337: 'Джемперы',
#  3344: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  3350: 'Кардиганы',
#  3354: 'Запарки и ароматизаторы',
#  3358: 'Термокружки',
#  3360: 'Беспроводные наушники',
#  3368: 'Муляжи камер видеонаблюдения',
#  3371: 'Комплекты',
#  3375: 'Спортивные костюмы',
#  3380: 'Босоножки',
#  3383: 'Перчатки хозяйственные',
#  3388: 'Автомобильные держатели',
#  3397: 'Подставки и держатели',
#  3404: 'Дуршлаги и сита',
#  3406: 'Перчатки хозяйственные',
#  3408: 'Гирлянды',
#  3412: 'Термокружки',
#  3417: 'Трусы',
#  3418: 'Емкости для специй и мельницы',
#  3422: 'Сушилки для посуды',
#  3427: 'Фрукто-овощерезки',
#  3432: 'Ночные рубашки и сорочки',
#  3433: 'Полотенца кухонные',
#  3439: 'Пакеты подарочные',
#  3440: 'Инструменты и принадлежности',
#  3444: 'Сувенирные деньги',
#  3448: 'Аксессуары',
#  3450: 'Комплекты',
#  3462: 'Носки и подследники',
#  3463: 'Амулеты, обереги и талисманы',
#  3467: 'Раскраски, наборы для росписи',
#  3472: 'Крючки и держатели',
#  3476: 'Трусы',
#  3478: 'Украшение интерьера',
#  3486: 'Худи',
#  3502: 'Защитные стекла',
#  3523: 'Домашняя обувь',
#  3539: 'Чехлы',
#  3541: 'Конверты',
#  3543: 'Чехлы для обуви',
#  3544: 'Носки, пинетки',
#  3551: 'Пакеты подарочные',
#  3558: 'Нижнее белье',
#  3559: 'Защитные стекла',
#  3561: 'Города и архитектура',
#  3564: 'Фартуки кухонные',
#  3578: 'Кабели',
#  3582: 'Создание украшений',
#  3583: 'Вакуумные пакеты',
#  3588: 'Платья',
#  3599: 'Новогодние сувениры и подарки',
#  3601: 'Худи',
#  3610: 'Часы',
#  3621: 'Умные часы',
#  3624: 'Легинсы и лосины',
#  3626: 'Пакеты фасовочные',
#  3645: 'Перчатки хозяйственные',
#  3652: 'Декоративные ленты',
#  3663: 'Фоторамки',
#  3665: 'Магниты',
#  3685: 'Внешние аккумуляторы',
#  3686: 'Пододеяльники',
#  3692: 'Автомобильные держатели',
#  3711: 'Букеты из мыла',
#  3713: 'Пижамы',
#  3719: 'Носки и подследники',
#  3728: 'Проводные наушники',
#  3730: 'Водолазки',
#  3737: 'Беспроводные наушники',
#  3743: 'Термобелье',
#  3749: 'Чехлы',
#  3762: 'Брюки',
#  3763: 'Ароматы для дома',
#  3769: 'Пакеты подарочные',
#  3784: 'Блоки питания',
#  3789: 'Носки и подследники',
#  3790: 'Открытки',
#  3796: 'Ремешки',
#  3802: 'Открытки',
#  3804: 'Сувениры',
#  3808: 'Стаканы',
#  3809: 'Блюда',
#  3811: 'Моноподы для селфи',
#  3812: 'Колготки',
#  3820: 'Упаковочная бумага',
#  3821: 'Копилки',
#  3824: 'Материалы для рукоделия',
#  3825: 'Инструменты для рукоделия',
#  3831: 'Маркеры',
#  3833: 'Беспроводные наушники',
#  3834: 'Полотенца кухонные',
#  3835: 'Пакеты подарочные',
#  3837: 'Пульты ДУ',
#  3841: 'Худи',
#  3847: 'Защитные стекла',
#  3853: 'Гольфы и гетры',
#  3856: 'Свечи для торта',
#  3861: 'Топперы для торта',
#  3882: 'Аксессуары для сушки белья',
#  3886: 'Сувениры',
#  3897: 'Худи',
#  3911: 'Подставки для чайных пакетиков',
#  3921: 'Плетение',
#  3929: 'Чехлы для наушников',
#  3931: 'Адаптеры и переходники',
#  3936: 'Чехлы',
#  3949: 'Свечи',
#  3951: 'Органайзеры и разделители',
#  3957: 'Коробки, корзины, контейнеры',
#  3966: 'Чехлы и сумки для планшетов и электронных книг',
#  3985: 'Носки и подследники',
#  3993: 'Пазлы',
#  4006: 'Гольфы и гетры',
#  4018: 'Платья повседневные',
#  4031: 'Чехлы',
#  4035: 'Комплекты постельного белья',
#  4036: 'Свадебные товары',
#  4042: 'Банки и крышки',
#  4047: 'Безмены и весы',
#  4059: 'Автомобильные держатели',
#  4066: 'Вешалки-плечики',
#  4071: 'Предметы интерьера бани',
#  4073: 'Коврики придверные',
#  4077: 'Гадальные карты',
#  4081: 'Моделирование',
#  4095: 'Гейзерные кофеварки',
#  4099: 'Топы',
#  4113: 'Новогодний декор',
#  4122: 'Джинсы',
#  4125: 'Стекломои и скребки',
#  4142: 'Аксессуары',
#  4143: 'Комплектующие',
#  4156: 'Рюкзаки, чехлы, сумки для ноутбуков',
#  4161: 'Сумки хозяйственные',
#  4166: 'Батарейки',
#  4168: 'Таймеры кухонные',
#  4173: 'Рыбочистки и зажимы',
#  4177: 'Сковороды',
#  4195: 'Трусы',
#  4221: 'Открытки',
#  4225: 'Джемперы',
#  4226: 'Этажерки и обувницы',
#  4231: 'Кабели',
#  4232: 'Гирлянды',
#  4242: 'Термосы',
#  4251: 'Умные часы',
#  4258: 'Органайзеры и разделители',
#  4260: 'Верхняя одежда',
#  4262: 'Фурнитура',
#  4271: 'Вешалки напольные',
#  4277: 'Сувениры',
#  4282: 'Умные часы',
#  4289: 'Колготки',
#  4290: 'Пряжа',
#  4291: 'Воздушные шары',
#  4292: 'Машинки для удаления катышек',
#  4296: 'Автомобильные держатели',
#  4297: 'Сменные картриджи для фильтров-кувшинов',
#  4299: 'Римские свечи и фонтаны',
#  4301: 'Пакеты и мешочки многоразовые',
#  4303: 'Воздушные шары',
#  4304: 'Открытки',
#  4314: 'Штативы',
#  4319: 'Геймпады, джойстики и триггеры',
#  4321: 'Боди и комбинезоны',
#  4323: 'Футболки',
#  4327: 'Колготки',
#  4337: 'Анатомические подушки',
#  4343: 'Кабели',
#  4344: 'Гольфы и гетры',
#  4352: 'Кабели',
#  4356: 'Воздушные шары',
#  4357: 'Носки и подследники',
#  4358: 'Майки',
#  4376: 'Чехлы',
#  4386: 'Гравюры',
#  4388: 'Ёлки искусственные',
#  4400: 'Трусы',
#  4413: 'Майки и топы бельевые',
#  4415: 'Ароматы для дома',
#  4428: 'Коробки, корзины, контейнеры',
#  4429: 'Наборы для рисования песком',
#  4434: 'Носки и подследники',
#  4437: 'Носки и подследники',
#  4447: 'Магические аксессуары и материалы',
#  4449: 'Джибитсы',
#  4460: 'Устройства измерения крепости',
#  4461: 'Комплекты белья',
#  4472: 'Запарки и ароматизаторы',
#  4485: 'Автомобильные держатели',
#  4487: 'Моноподы для селфи',
#  4512: 'Электрогрелки',
#  4517: 'Чехлы',
#  4520: 'Автомобильные держатели',
#  4533: 'Анатомические подушки',
#  4542: 'Футболки',
#  4543: 'Пакеты и мешочки многоразовые',
#  4544: 'Стельки и вставки',
#  4562: 'Носки, пинетки',
#  4565: 'Сушилки для посуды',
#  4568: 'Алмазные мозаики',
#  4569: 'Дуршлаги и сита',
#  4577: 'Аксессуары',
#  4579: 'Кувшины и графины',
#  4592: 'Батарейки',
#  4593: 'Аксессуары',
#  4597: 'Беспроводные наушники',
#  4625: 'Кабели',
#  4635: 'Стикеры',
#  4653: 'Беспроводные наушники',
#  4657: 'Домашние платья и туники',
#  4663: 'Пакеты и мешочки многоразовые',
#  4668: 'Стикеры',
#  4680: 'Футболки',
#  4686: 'Коробки, корзины, контейнеры',
#  4687: 'Беспроводные наушники',
#  4689: 'Спортивные костюмы',
#  4690: 'Чистящие средства',
#  4705: 'Подставки и держатели',
#  4718: 'Украшения',
#  4724: 'Искусственный снег',
#  4729: 'Карты памяти',
#  4731: 'Свечи',
#  4734: 'Кружки',
#  4744: 'Свадебные товары',
#  4745: 'Нижнее белье',
#  4748: 'Батарейки',
#  4750: 'Алмазные мозаики',
#  4756: 'Коннекторы',
#  4761: 'Чаши',
#  4780: 'Носки и подследники',
#  4793: 'Наклейки и пленки',
#  4799: 'Прочие приставки',
#  4806: 'Ножи кухонные',
#  4818: 'Гирлянды-растяжки',
#  4821: 'Защитные стекла',
#  4827: 'Предметы интерьера бани',
#  4831: 'Внешние аккумуляторы',
#  4842: 'Защитные стекла',
#  4857: 'Фрукто-овощечистки',
#  4861: 'Аксессуары',
#  4870: 'Пуфики и банкетки',
#  4878: 'Слипоны',
#  4880: 'Искусственные цветы',
#  4890: 'Адаптеры и переходники',
#  4894: 'Таблички, номера и крючки',
#  4911: 'Шторы и портьеры',
#  4952: 'Материалы для рукоделия',
#  4955: 'Защитные пленки',
#  4968: 'Стикеры',
#  4980: 'Материалы для рукоделия',
#  4982: 'Батарейки',
#  5020: 'Носки и подследники',
#  5029: 'Банки и крышки',
#  5031: 'Раскраски, наборы для росписи',
#  5045: 'Наклейки и пленки',
#  5063: 'Рейлинг',
#  5073: 'Ночные рубашки и сорочки',
#  5087: 'Чехлы',
#  5097: 'Фрукто-овощечистки',
#  5107: 'Пледы',
#  5115: 'Носки и подследники',
#  5129: 'Боди и комбинезоны',
#  5140: 'Футболки',
#  5158: 'Карты памяти',
#  5159: 'Защитные стекла',
#  5175: 'Новогодние сувениры и подарки',
#  5189: 'Органайзеры и разделители',
#  5194: 'Коробки',
#  5201: 'Крепления и подставки',
#  5202: 'Термометры, барометры',
#  5215: 'Чехлы',
#  5218: 'Автомобильные держатели',
#  5222: 'Штативы',
#  5254: 'Подставки и держатели',
#  5273: 'Носки и подследники',
#  5280: 'Кабели',
#  5289: 'Держатели, подставки и подносы',
#  5296: 'Трусы',
#  5299: 'Комплекты постельного белья',
#  5310: 'Термосы',
#  5313: 'Кабели и зарядные устройства',
#  5332: 'Защитные стекла',
#  5342: 'Термосы',
#  5344: 'Трусы',
#  5353: 'Миски и салатницы',
#  5372: 'Часы',
#  5374: 'Защитные стекла',
#  5388: 'Худи',
#  5406: 'Гирлянды',
#  5413: 'Кардиганы',
#  5415: 'Сетевые зарядные устройства',
#  5416: 'Кабели',
#  5423: 'Наборы, ингредиенты для приготовления алкоголя',
#  5425: 'Наполнители упаковочные',
#  5432: 'Подушки декоративные',
#  5437: 'Наборы, ингредиенты для приготовления алкоголя',
#  5442: 'Тряпки, салфетки и губки',
#  5447: 'Инструменты',
#  5448: 'Подставки для ноутбуков',
#  5454: 'Спортивные костюмы',
#  5458: 'Чехлы',
#  5483: 'Подушки декоративные',
#  5486: 'Держатели для кабелей',
#  5491: 'Планшеты',
#  5497: 'Сетевые зарядные устройства',
#  5499: 'Магниты',
#  5502: 'Беспроводные наушники',
#  5507: 'Скетчбуки',
#  5509: 'Умные часы',
#  5515: 'Материалы для рукоделия',
#  5560: 'Шнуры и шнурки',
#  5563: 'Чехлы для наушников',
#  5566: 'Футболки и лонгсливы',
#  5567: 'Проводные наушники',
#  5569: 'Крышки для посуды',
#  5570: 'Геймпады, джойстики и триггеры',
#  5572: 'Автомобильные держатели',
#  5575: 'Майки и топы бельевые',
#  5581: 'Геймпады, джойстики и триггеры',
#  5587: 'Штативы',
#  5600: 'Сувениры',
#  5602: 'Носки и подследники',
#  5604: 'Фитнес браслеты',
#  5609: 'Пряжа',
#  5610: 'Чехлы для наушников',
#  5614: 'Столовые приборы одноразовые',
#  5618: 'Носки и подследники',
#  5628: 'Раскраски, наборы для росписи',
#  5632: 'Геймпады, джойстики и триггеры',
#  5658: 'Краски, пигменты',
#  5660: 'Сетевые зарядные устройства',
#  5663: 'Наборы, ингредиенты для приготовления алкоголя',
#  5670: 'Гирлянды',
#  5675: 'Комплекты',
#  5684: 'Защитные стекла',
#  5695: 'Беспроводные наушники',
#  5696: 'Аккумуляторные батарейки',
#  5706: 'Носки и подследники',
#  5719: 'Коробки',
#  5720: 'Кабели',
#  5721: 'Щетки и губки',
#  5753: 'Носки и подследники',
#  5760: 'Свечи',
#  5761: 'Трусы',
#  5766: 'Запарки и ароматизаторы',
#  5776: 'Защитные стекла',
#  5785: 'Планшеты для рисования',
#  5787: 'Футболки',
#  5788: 'Запарки и ароматизаторы',
#  5820: 'Чехлы',
#  5822: 'Чехлы',
#  5837: 'Скалки',
#  5845: 'Крючки и держатели',
#  5902: 'Толстовки и свитшоты',
#  5907: 'KVM-консоли и кабели',
#  5916: 'Защитные стекла',
#  5941: 'Искусственные цветы',
#  5951: 'Соковыжималки',
#  5960: 'Инструменты',
#  5962: 'Травяные',
#  5979: 'Купальники',
#  5981: 'Материалы для рукоделия',
#  5982: 'Носки и подследники',
#  6005: 'Футболки',
#  6007: 'Аксессуары для коктейлей',
#  6008: 'Чехлы',
#  6028: 'Фрукто-овощерезки',
#  6040: 'Автомобильные держатели',
#  6045: 'Гирлянды',
#  6048: 'Пряжа',
#  6057: 'Коробки, корзины, контейнеры',
#  6061: 'Трусы',
#  6076: 'Проводные наушники',
#  6091: 'Часы',
#  6092: 'Полотенца',
#  6095: 'Аксессуары для наушников',
#  6106: 'Спортивные шорты',
#  6108: 'Елочные игрушки и украшения',
#  6128: 'Подставки и держатели',
#  6138: 'Носки и подследники',
#  6153: 'Аппликации',
#  6157: 'Аккумуляторные батарейки',
#  6171: 'Фрукто-овощерезки',
#  6206: 'Кисти',
#  6209: 'Открытки',
#  6220: 'Платья повседневные',
#  6225: 'Одеяла',
#  6230: 'Футболки',
#  6232: 'Пазлы',
#  6237: 'Чехлы и сумки для планшетов и электронных книг',
#  6239: 'Подставки и держатели',
#  6242: 'Вантузы и тросы',
#  6244: 'Чехлы для наушников',
#  6246: 'Термобелье',
#  6247: 'Носки и подследники',
#  6248: 'Чаши',
#  6261: 'Комбинезоны и брюки утепленные',
#  6264: 'Подставки и держатели',
#  6268: 'Носки и подследники',
#  6271: 'Товары к Пасхе',
#  6278: 'Гирлянды',
#  6285: 'Емкости для специй и мельницы',
#  6289: 'Носки и подследники',
#  6296: 'Защитные стекла',
#  6302: 'Тряпки, салфетки и губки',
#  6303: 'Чистящие средства',
#  6306: 'Заварочные чайники',
#  6310: 'Раскраски, наборы для росписи',
#  6333: 'Стаканы',
#  6335: 'Батарейки',
#  6340: 'Фитнес браслеты',
#  6343: 'Елочные игрушки и украшения',
#  6351: 'Полотенца',
#  6356: 'Декоративные ленты',
#  6401: 'Елочные игрушки и украшения',
#  6405: 'Носки, пинетки',
#  6409: 'Контейнеры и ланч-боксы',
#  6416: 'Наволочки',
#  6420: 'Колготки',
#  6422: 'Майки',
#  6424: 'Стикеры',
#  6430: 'Тряпки, салфетки и губки',
#  6437: 'Парики',
#  6448: 'Шапки для бани',
#  6470: 'Геймпады, джойстики и триггеры',
#  6475: 'Вешалки настенные',
#  6477: 'Полотенца',
#  6479: 'Материалы для рукоделия',
#  6482: 'Аксессуары для стирки',
#  6492: 'Украшение интерьера',
#  6499: 'Майки',
#  6504: 'Диспенсеры, дозаторы',
#  6505: 'Материалы для рукоделия',
#  6512: 'Фоторамки',
#  6525: 'Кастрюли, ковши',
#  6530: 'Инструменты для рукоделия',
#  6541: 'Водолазки',
#  6542: 'Термобелье',
#  6554: 'Наборы для покера',
#  6561: 'Ножи кухонные',
#  6568: 'Футболки',
#  6576: 'Спецодежда рабочая',
#  6581: 'Краски, пигменты',
#  6596: 'Полотенца',
#  6599: 'Адаптеры и переходники',
#  6600: 'Комбинезоны повседневные',
#  6605: 'Контейнеры и ланч-боксы',
#  6610: 'Пижамы',
#  6623: 'Материалы для рукоделия',
#  6628: 'Носки и подследники',
#  6639: 'Беспроводные наушники',
#  6643: 'Карандаши',
#  6656: 'Шторы и портьеры',
#  6658: 'Алмазные мозаики',
#  6664: 'Коврики для мыши',
#  6673: 'Носки и подследники',
#  6676: 'Фурнитура',
#  6679: 'Животные и птицы',
#  6685: 'Новогодние сувениры и подарки',
#  6692: 'Устройства для парения',
#  6704: 'Тряпки, салфетки и губки',
#  6705: 'Стекла',
#  6715: 'Комплекты',
#  6731: 'Купальники',
#  6734: 'Украшение интерьера',
#  6735: 'Чехлы',
#  6741: 'Носки и подследники',
#  6776: 'Халаты',
#  6780: 'Запарки и ароматизаторы',
#  6783: 'Декоративные ленты',
#  6787: 'Чехлы',
#  6795: 'Товары для самокруток',
#  6796: 'Емкости для жидкостей',
#  6815: 'Чехлы',
#  6835: 'Защитные стекла',
#  6838: 'Тряпки, салфетки и губки',
#  6842: 'Краски, пигменты',
#  6845: 'Проводные наушники',
#  6866: 'Термопасты и термопрокладки',
#  6873: 'Упаковочная бумага',
#  6877: 'Свитеры',
#  6890: 'Накидки и килты',
#  6904: 'Футболки',
#  6916: 'Сетевые зарядные устройства',
#  6918: 'Защитные стекла',
#  6932: 'Кабели',
#  6939: 'Легинсы и лосины',
#  6940: 'Скрапбукинг',
#  6943: 'Ремешки',
#  6951: 'Стикеры',
#  6961: 'Аксессуары для спецодежды',
#  6962: 'Салфетки бумажные',
#  6971: 'Брюки',
#  6982: 'Формы для пельменей',
#  7020: 'Бюстгальтеры',
#  7022: 'Геймпады, джойстики и триггеры',
#  7030: 'Проводные наушники',
#  7039: 'Футболки',
#  7043: 'Носки и подследники',
#  7050: 'Крючки и держатели',
#  7069: 'Ритуальные товары',
#  7080: 'Планшеты для рисования',
#  7083: 'Носки и подследники',
#  7088: 'Комплекты для бани',
#  7092: 'Носки и подследники',
#  7111: 'Вешалки настенные',
#  7120: 'Футболки и майки домашние',
#  7121: 'Боди и комбинезоны',
#  7123: 'Комплекты на выписку',
#  7133: 'Кисти',
#  7147: 'Футболки',
#  7149: 'Настольные игры',
#  7156: 'Портативная акустика',
#  7167: 'Угги',
#  7177: 'Беспроводные наушники',
#  7205: 'Емкости для жидкостей',
#  7213: 'Свет для фотостудии',
#  7219: 'Постеры',
#  7225: 'Стикеры',
#  7229: 'Пледы',
#  7233: 'Автомобильные держатели',
#  7252: 'Топперы для торта',
#  7253: 'Комплекты белья',
#  7262: 'Салфетницы',
#  7270: 'Часы',
#  7278: 'Тряпки, салфетки и губки',
#  7290: 'Носки, пинетки',
#  7292: 'Брюки',
#  7306: 'Худи',
#  7310: 'Чехлы для наушников',
#  7312: 'Школьная форма для девочек',
#  7328: 'Домашняя одежда',
#  7330: 'Термобелье',
#  7334: 'Спортивные костюмы',
#  7338: 'Полки и скамьи',
#  7349: 'Конверты',
#  7352: 'Материалы для рукоделия',
#  7357: 'Настольные игры',
#  7361: 'Платья повседневные',
#  7366: 'Автомобильные держатели',
#  7369: 'Раскраски, наборы для росписи',
#  7371: 'Пижамы',
#  7393: 'Трусы',
#  7399: 'Украшение интерьера',
#  7400: 'Магниты',
#  7405: 'Плетение',
#  7408: 'Носки и подследники',
#  7410: 'Носки и подследники',
#  7421: 'Краски, пигменты',
#  ...}

# %% [markdown]
# ### Векторизация

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.corpus import stopwords 
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Дмитрий\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('russian'))

# %%
corpus_train = train['lemm'].values.astype('U')
corpus_test = test['lemm'].values.astype('U')

# %%
# С помощью TF-IDF
# Эта переменая содержит настройку того,
# как векторайзер будет воспринимать слова

token_pattern_ = r'\w{1,}'
count_tf_idf = TfidfVectorizer(stop_words=list(stop_words), min_df=3,  max_features=None, 
            token_pattern = token_pattern_,
            ngram_range=(1, 2), use_idf=1, smooth_idf=1, sublinear_tf=1,
            )

# %%
tf_idf_train = count_tf_idf.fit_transform(corpus_train)
tf_idf_test = count_tf_idf.transform(corpus_test)

# %%
tf_idf_train.shape
# Out:
# (91120, 27297)

# %% [markdown]
# ### Определим самые популярные слова в категориях

# %%
levels_id = pd.DataFrame()

# %%
# переводим категории в числа
level_1 = train.level_1.factorize()[0]

# %%
# Вывел кодирование в отдельную таблицу
levels_id['level_1_id'] = level_1
levels_id['level_1'] = train['level_1']

# %%
category_id_df = levels_id[['level_1', 'level_1_id']].drop_duplicates().sort_values('level_1_id')

# %%
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['level_1_id', 'level_1']].values)

# %%
id_to_category
# Out:
# {0: 'Электроника',
#  1: 'Одежда',
#  2: 'Хобби и творчество',
#  3: 'Товары для дома',
#  4: 'Обувь'}

# %%
# tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', ngram_range =(1, 2), stop_words=stop_words)

# features = tfidf.fit_transform(corpus_train).toarray()

# labels = lemmatized['level_1_id']

# features.shape

# %%
features = tf_idf_train
labels = levels_id['level_1_id']

# %%
from sklearn.feature_selection import chi2

N = 4
for Product, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(count_tf_idf.get_feature_names_out())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    #trigrams = [v for v in feature_names if len(v.split(' ')) == 3]
    print("# '{}':".format(Product))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
    #print("  . Most correlated trigrams:\n. {}".format('\n. '.join(trigrams[-N:])))
# Out:
# # 'Обувь':
#   . Most correlated unigrams:
# . стелька
# . ботинок
# . тапочек
# . кроссовок
#   . Most correlated bigrams:
# . ботинок женский
# . кроссовок мужской
# . тапочек комнатный
# . кроссовок женский
# # 'Одежда':
#   . Most correlated unigrams:
# . трусы
# . футболка
# . носок
# . женский
#   . Most correlated bigrams:
# . футболка женский
# . носок мужской
# . носок женский
# . трусы женский
# # 'Товары для дома':
#   . Most correlated unigrams:
# . чехол
# . женский
# . подарочный
# . пакет
#   . Most correlated bigrams:
# . samsung galaxy
# . пакет подарочный
# . день рождение
# . защитный стекло
# # 'Хобби и творчество':
#   . Most correlated unigrams:
# . холст
# . подрамник
# . картина
# . номер
#   . Most correlated bigrams:
# . алмазный мозаика
# . номер холст
# . холст подрамник
# . картина номер
# # 'Электроника':
#   . Most correlated unigrams:
# . samsung
# . защитный
# . iphone
# . чехол
#   . Most correlated bigrams:
# . чехол samsung
# . xiaomi redmi
# . samsung galaxy
# . защитный стекло

# %% [markdown]
# ### Обучение моделей
# - Logistic Regression
# - (Multinomial) Naive Bayes
# - Linear Support Vector Machine
# - Random Forest

# %% [markdown]
# Таблицы должны быть подготовлены в предыдущей части

# %% [markdown]
# Поиск подходящей модели будем осуществлять с момощью RandomSearch

# %%
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer

# %%
enc = OrdinalEncoder()

# %%
ct = make_column_transformer((OrdinalEncoder(), ['level_1', 'level_2', 'level_3', 'level_4']),
                             remainder='passthrough')

# %%
a = ct.fit_transform(train)

# %%
# Способ декодировать данные трансформера
#a_2 = ct.named_transformers_['ordinalencoder'].inverse_transform(train_coder.loc[:,'title':'level_4'].values)

# %%
train_coder = pd.DataFrame(a)

# %%
train_coder.head()
# Out:
#      0     1      2      3                              4                 5  \
# 0  4.0  28.0   18.0  163.0  Зарядный кабель Borofone B...            Кабели
# 1  1.0   6.0   35.0  591.0                     Трусы Sela             Трусы
# 2  3.0  25.0  119.0  266.0  Гуашь "ЮНЫЙ ВОЛШЕБНИК", 12...  Краски, пигменты
# 3  3.0  36.0   97.0  231.0  Колба для кальяна Крафт (р...             Колбы
# 4  1.0   6.0   73.0  395.0  Пижама женская, однотонная...            Пижамы
#
#                                6      7
# 0  зарядный кабель borofone l...   9031
# 1                     трусы sela  18305
# 2  гуашь юный волшебник цвето...  16357
# 3  колба кальян крафт разный ...  34666
# 4  пижама женский однотонный ...  26389

# %%
y_table = train_coder.drop([4,5,6], axis=1).astype('int')

# %%
y_table
# Out:
#        0   1    2    3      7
# 0      4  28   18  163   9031
# 1      1   6   35  591  18305
# 2      3  25  119  266  16357
# 3      3  36   97  231  34666
# 4      1   6   73  395  26389
# ...   ..  ..  ...  ...    ...
# 91115  4  28   18  166   4955
# 91116  3  23   21   26  19626
# 91117  2  38  161  375  22291
# 91118  4  33  149  463   2985
# 91119  4  33  149  463   2985
#
# [91120 rows x 5 columns]

# %%
X = features

# %%
LR = LogisticRegression(random_state=12345, multi_class='auto')

# %%
# %%time
LR.fit(X, y_table[0])
# Out:
# CPU times: total: 812 ms
# Wall time: 3.05 s
# LogisticRegression(random_state=12345)

# %%
y_0 = LR.predict(X)

# %%
f1_score(y_table[0], y_0, average='micro')
# Out:
# 0.9841856892010535

# %%
y_0_0 = y_0.reshape(-1,1)

# %%
X_array = X.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 X_array = X.toarray()
#
# File D:\DataScience\anaconda\lib\site-packages\scipy\sparse\_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File D:\DataScience\anaconda\lib\site-packages\scipy\sparse\_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 18.5 GiB for an array with shape (91120, 27297) and data type float64

# %%
X_array[1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
X_2 = np.concatenate([X_array, y_0_0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 X_2 = np.concatenate([X_array, y_0_0], axis=1)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 18.5 GiB for an array with shape (91120, 27298) and data type float64

# %%
from scipy.sparse import csr_matrix,hstack

# %%
S = csr_matrix(y_0_0)

# %%
S
# Out:
# <91120x1 sparse matrix of type '<class 'numpy.intc'>'
# 	with 89536 stored elements in Compressed Sparse Row format>

# %%
X_2 = hstack([X, S])

# %%
print(type(X_2))
print(X.shape)
print(X_2.shape)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# (91120, 27297)
# (91120, 27298)

# %%
LR_2 = LogisticRegression(random_state=12345, multi_class='auto')

# %%
# %%time
LR_2.fit(X_2, y_table[1])
# Out:
# CPU times: total: 8.34 s
# Wall time: 21.1 s
# LogisticRegression(random_state=12345)

# %%
y_1 = LR_2.predict(X_2)

# %%
f1_score(y_table[1], y_1, average='micro')
# Out:
# 0.9115452151009658

# %%
y_1_1 = y_1.reshape(-1,1)

# %%
S = csr_matrix(y_1_1)

# %%
X_3 = hstack([X_2, S])

# %%
LR_3 = LogisticRegression(random_state=12345, multi_class='auto')

# %%
# %%time
LR_3.fit(X_3, y_table[2])
# Out:
# CPU times: total: 45.1 s
# Wall time: 1min 59s
# LogisticRegression(random_state=12345)

# %%
y_2 = LR_3.predict(X_3)

# %%
f1_score(y_table[2], y_2, average='micro')
# Out:
# 0.39108867427568045

# %%
LR_solo = LogisticRegression(random_state=12345, multi_class='auto')

# %%
# %%time
LR_solo.fit(X, y_table[2])
# Out:
# CPU times: total: 39.7 s
# Wall time: 1min 55s
# LogisticRegression(random_state=12345)

# %%
y_solo = LR_solo.predict(X)

# %%
f1_score(y_table[2], y_solo, average='micro')
# Out:
# 0.9091966637401229

# %%
X_2 = np.concatenate([X, y_1_1], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_49/4226446373.py in <module>
# ----> 1 X_2 = np.concatenate([X, y_1_1], axis=1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
import numpy as np
from scipy.sparse import csr_matrix
from scipy import sparse

# %%
A = np.array(X)
print(A.shape, type(A), X.shape)
# Out:
# () <class 'numpy.ndarray'> (91120, 25405)

# %%
B = np.array(y_1)
print(B.shape, type(B))
# Out:
# (91120,) <class 'numpy.ndarray'>

# %%
np.hstack((X, y_1.reshape(-1,1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_49/2547024431.py in <module>
# ----> 1 np.hstack((X, y_1.reshape(-1,1)))
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/numpy/core/shape_base.py in hstack(tup)
#     341     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     342     if arrs and arrs[0].ndim == 1:
# --> 343         return _nx.concatenate(arrs, 0)
#     344     else:
#     345         return _nx.concatenate(arrs, 1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
y_1.shape
# Out:
# (91120,)

# %%
y_1.reshape

# %%
type(y_1.reshape(-1,1))
# Out:
# numpy.ndarray

# %%
X_array = np.array(X)

# %%
X_array.shape
# Out:
# ()

# %%
pd.DataFrame(a_2).head()
# Out:
#                     0                     1                      2  \
# 0         Электроника  Смартфоны и телефоны  Аксессуары и запчасти
# 1              Одежда        Женская одежда     Белье и купальники
# 2  Хобби и творчество             Рисование       Краски, пигменты
# 3  Хобби и творчество    Товары для курения   Кальяны и аксессуары
# 4              Одежда        Женская одежда        Домашняя одежда
#
#                               3                 4
# 0  Зарядные устройства и кабели            Кабели
# 1                         Трусы             Трусы
# 2              Краски, пигменты  Краски, пигменты
# 3                         Колбы             Колбы
# 4                        Пижамы            Пижамы

# %% [markdown]
# Итак, как список последовательных таргетов у нас будут столбцы с уровнями, закодированные с помощью Ordinal Encoder.

# %%
train
# Out:
#                                title             level_1  \
# 0      Зарядный кабель Borofone B...         Электроника
# 1                         Трусы Sela              Одежда
# 2      Гуашь "ЮНЫЙ ВОЛШЕБНИК", 12...  Хобби и творчество
# 3      Колба для кальяна Крафт (р...  Хобби и творчество
# 4      Пижама женская, однотонная...              Одежда
# ...                              ...                 ...
# 91115  Прочное стекло 2D на Samsu...         Электроника
# 91116  Алмазная мозаика "Ромашки"...  Хобби и творчество
# 91117  Открытка "Вместе навсегда"...     Товары для дома
# 91118       Пульт K10B-C1 для Rolsen         Электроника
# 91119  Пульт DS300A/DC300A/DN300 ...         Электроника
#
#                          level_2                       level_3  \
# 0           Смартфоны и телефоны         Аксессуары и запчасти
# 1                 Женская одежда            Белье и купальники
# 2                      Рисование              Краски, пигменты
# 3             Товары для курения          Кальяны и аксессуары
# 4                 Женская одежда               Домашняя одежда
# ...                          ...                           ...
# 91115       Смартфоны и телефоны         Аксессуары и запчасти
# 91116    Пазлы, мозаика и фреска              Алмазные мозаики
# 91117      Товары для праздников           Открытки и конверты
# 91118  Телевизоры и видеотехника  Оборудование для телевизоров
# 91119  Телевизоры и видеотехника  Оборудование для телевизоров
#
#                             level_4           level_5  \
# 0      Зарядные устройства и кабели            Кабели
# 1                             Трусы             Трусы
# 2                  Краски, пигменты  Краски, пигменты
# 3                             Колбы             Колбы
# 4                            Пижамы            Пижамы
# ...                             ...               ...
# 91115      Защитные стекла и пленки   Защитные стекла
# 91116              Алмазные мозаики  Алмазные мозаики
# 91117                      Открытки          Открытки
# 91118                     Пульты ДУ         Пульты ДУ
# 91119                     Пульты ДУ         Пульты ДУ
#
#                                 lemm
# 0      зарядный кабель для айфон м\n
# 1                            трусы\n
# 2      гуашь юный волшебник цвето...
# 3      колба для кальян крафт раз...
# 4      пижама женский однотонный ...
# ...                              ...
# 91115            прочный стекло на\n
# 91116  алмазный мозаика ромашка с...
# 91117  открытка вместе навсегда в...
# 91118                    пульт для\n
# 91119  пульт для цифровой пристав...
#
# [91120 rows x 7 columns]

# %%
train_coder
# Out:
#       title level_1 level_2 level_3 level_4                        level_5  \
# 0       4.0    28.0    18.0   163.0   193.0  Зарядный кабель Borofone B...
# 1       1.0     6.0    35.0   591.0   620.0                     Трусы Sela
# 2       3.0    25.0   119.0   266.0   272.0  Гуашь "ЮНЫЙ ВОЛШЕБНИК", 12...
# 3       3.0    36.0    97.0   231.0   235.0  Колба для кальяна Крафт (р...
# 4       1.0     6.0    73.0   395.0   407.0  Пижама женская, однотонная...
# ...     ...     ...     ...     ...     ...                            ...
# 91115   4.0    28.0    18.0   166.0   172.0  Прочное стекло 2D на Samsu...
# 91116   3.0    23.0    21.0    26.0    29.0  Алмазная мозаика "Ромашки"...
# 91117   2.0    38.0   161.0   375.0   387.0  Открытка "Вместе навсегда"...
# 91118   4.0    33.0   149.0   463.0   479.0       Пульт K10B-C1 для Rolsen
# 91119   4.0    33.0   149.0   463.0   479.0  Пульт DS300A/DC300A/DN300 ...
#
#                                 lemm
# 0      зарядный кабель для айфон м\n
# 1                            трусы\n
# 2      гуашь юный волшебник цвето...
# 3      колба для кальян крафт раз...
# 4      пижама женский однотонный ...
# ...                              ...
# 91115            прочный стекло на\n
# 91116  алмазный мозаика ромашка с...
# 91117  открытка вместе навсегда в...
# 91118                    пульт для\n
# 91119  пульт для цифровой пристав...
#
# [91120 rows x 7 columns]

# %%
# Out:
#                                title             level_1  \
# 0      Зарядный кабель Borofone B...         Электроника
# 1                         Трусы Sela              Одежда
# 2      Гуашь "ЮНЫЙ ВОЛШЕБНИК", 12...  Хобби и творчество
# 3      Колба для кальяна Крафт (р...  Хобби и творчество
# 4      Пижама женская, однотонная...              Одежда
# ...                              ...                 ...
# 91115  Прочное стекло 2D на Samsu...         Электроника
# 91116  Алмазная мозаика "Ромашки"...  Хобби и творчество
# 91117  Открытка "Вместе навсегда"...     Товары для дома
# 91118       Пульт K10B-C1 для Rolsen         Электроника
# 91119  Пульт DS300A/DC300A/DN300 ...         Электроника
#
#                          level_2                       level_3  \
# 0           Смартфоны и телефоны         Аксессуары и запчасти
# 1                 Женская одежда            Белье и купальники
# 2                      Рисование              Краски, пигменты
# 3             Товары для курения          Кальяны и аксессуары
# 4                 Женская одежда               Домашняя одежда
# ...                          ...                           ...
# 91115       Смартфоны и телефоны         Аксессуары и запчасти
# 91116    Пазлы, мозаика и фреска              Алмазные мозаики
# 91117      Товары для праздников           Открытки и конверты
# 91118  Телевизоры и видеотехника  Оборудование для телевизоров
# 91119  Телевизоры и видеотехника  Оборудование для телевизоров
#
#                             level_4           level_5  \
# 0      Зарядные устройства и кабели            Кабели
# 1                             Трусы             Трусы
# 2                  Краски, пигменты  Краски, пигменты
# 3                             Колбы             Колбы
# 4                            Пижамы            Пижамы
# ...                             ...               ...
# 91115      Защитные стекла и пленки   Защитные стекла
# 91116              Алмазные мозаики  Алмазные мозаики
# 91117                      Открытки          Открытки
# 91118                     Пульты ДУ         Пульты ДУ
# 91119                     Пульты ДУ         Пульты ДУ
#
#                                 lemm
# 0      зарядный кабель для айфон м\n
# 1                            трусы\n
# 2      гуашь юный волшебник цвето...
# 3      колба для кальян крафт раз...
# 4      пижама женский однотонный ...
# ...                              ...
# 91115            прочный стекло на\n
# 91116  алмазный мозаика ромашка с...
# 91117  открытка вместе навсегда в...
# 91118                    пульт для\n
# 91119  пульт для цифровой пристав...
#
# [91120 rows x 7 columns]

# %%
X_train = columns_pipeline.fit_transform(lemmatized)

# %%
X_train = pd.DataFrame(X_train, columns=[lemmatized.columns])
X_train
# Out:
#       level_1 level_2 level_3 level_4 level_5                           lemm  \
# 0         4.0    28.0    18.0   163.0   193.0  зарядный кабель для айфон м\n
# 1         1.0     6.0    35.0   591.0   620.0                        трусы\n
# 2         3.0    25.0   119.0   266.0   272.0  гуашь юный волшебник цвето...
# 3         3.0    36.0    97.0   231.0   235.0  колба для кальян крафт раз...
# 4         1.0     6.0    73.0   395.0   407.0  пижама женский однотонный ...
# ...       ...     ...     ...     ...     ...                            ...
# 91115     4.0    28.0    18.0   166.0   172.0            прочный стекло на\n
# 91116     3.0    23.0    21.0    26.0    29.0  алмазный мозаика ромашка с...
# 91117     2.0    38.0   161.0   375.0   387.0  открытка вместе навсегда в...
# 91118     4.0    33.0   149.0   463.0   479.0                    пульт для\n
# 91119     4.0    33.0   149.0   463.0   479.0  пульт для цифровой пристав...
#
#       category_id level_1_id
# 0           12171          0
# 1           14233          1
# 2           13429          2
# 3            2789          2
# 4           12834          1
# ...           ...        ...
# 91115       14922          0
# 91116       13028          2
# 91117       13407          3
# 91118       12100          0
# 91119       12100          0
#
# [91120 rows x 8 columns]

# %%
X = features_2
y = X_train['level_1']
y = y.astype('int')

# %%
pipeline = make_pipeline(columns_pipeline)
pipeline.steps.append(('clf', DummyRegressor()))
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat_encoder',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['level_1', 'level_2',
#                                                    'level_3', 'level_4',
#                                                    'level_5'])])),
#                 ('clf', DummyRegressor())])

# %%
LR = LogisticRegression(random_state=12345, multi_class='auto')

# %%
predict = LR.fit(X, y)

# %%
pred = predict.predict(X)

# %%
X_train['pred'] = pred

# %%
X_train
# Out:
#       level_1 level_2 level_3 level_4 level_5                           lemm  \
# 0         4.0    28.0    18.0   163.0   193.0  зарядный кабель для айфон м\n
# 1         1.0     6.0    35.0   591.0   620.0                        трусы\n
# 2         3.0    25.0   119.0   266.0   272.0  гуашь юный волшебник цвето...
# 3         3.0    36.0    97.0   231.0   235.0  колба для кальян крафт раз...
# 4         1.0     6.0    73.0   395.0   407.0  пижама женский однотонный ...
# ...       ...     ...     ...     ...     ...                            ...
# 91115     4.0    28.0    18.0   166.0   172.0            прочный стекло на\n
# 91116     3.0    23.0    21.0    26.0    29.0  алмазный мозаика ромашка с...
# 91117     2.0    38.0   161.0   375.0   387.0  открытка вместе навсегда в...
# 91118     4.0    33.0   149.0   463.0   479.0                    пульт для\n
# 91119     4.0    33.0   149.0   463.0   479.0  пульт для цифровой пристав...
#
#       category_id level_1_id pred
# 0           12171          0    4
# 1           14233          1    1
# 2           13429          2    3
# 3            2789          2    3
# 4           12834          1    1
# ...           ...        ...  ...
# 91115       14922          0    4
# 91116       13028          2    3
# 91117       13407          3    2
# 91118       12100          0    4
# 91119       12100          0    4
#
# [91120 rows x 9 columns]

# %%
from sklearn.metrics import f1_score
f1_score(y, pred, average='micro')

# %%
predict
# Out:
# LogisticRegression(random_state=12345)

# %%
f1_score(y, pred, average='micro')
# Out:
# 0.9830223880597015

# %%
X_train = columns_pipeline.inverse_transform(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_48/1637346042.py in <module>
# ----> 1 X_train = columns_pipeline.inverse_transform(y)
#
# AttributeError: 'ColumnTransformer' object has no attribute 'inverse_transform'

# %%
LR.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
params = [{
    'multi_class': ['auto', 'ovr', 'multinomial'],
    'max_iter': [i for i in np.arange(50, 200, 15)],
    'solver': ['newton-cg', 'sag', 'saga', 'lbfgs']
    }]

# params = [{
#     'clf': [LogisticRegression(random_state=12345)],
#     'clf__multi_class': ['auto', 'ovr', 'multinomial'],
#     'clf__max_iter': [i for i in np.arange(50, 200, 15)],
#     'clf__solver': ['newton-cg', 'sag', 'saga', 'lbfgs']
#     }]
#     {
#     'clf': [GradientBoostingRegressor(random_state=270323)],
#     'clf__n_estimators': [i for i in np.arange(100, 500, 10)],
#     'clf__max_depth': [i for i in np.arange(1, 15, 2)],
#     'clf__min_samples_split': [i for i in np.arange(4, 14, 2)],
#     'clf__max_features': ['auto', 'sqrt', 'log2'],
#     'columntransformer__num_cols__scaler': [None],
#     'columntransformer__cat_encoder__encoder': [None]
#     },
#     {
#     'clf': [RandomForestRegressor(random_state=270323)],
#     'clf__n_estimators': [i for i in np.arange(150, 500, 15)],
#     'clf__min_samples_split': [i for i in np.arange(4, 14, 2)],
#     'clf__bootstrap': [True, False],
#     'columntransformer__num_cols__scaler': [None],
#     'columntransformer__cat_encoder__encoder': [None]
#     },
#     {
#     'clf': [CatBoostRegressor(random_state=270323, verbose=0)],
#     'clf__n_estimators': estimators_range,
#     'clf__max_depth': max_depth_range,
#     'columntransformer__num_cols__scaler': [None],
#     'columntransformer__cat_encoder__encoder': [None]
#     }]

# %%
grid = RandomizedSearchCV(LR,
                    params,
                    n_iter=100,
                    cv=3,
                    verbose=2,
                    random_state=12345,
                    scoring='f1',
                    n_jobs=-1)

# %%
grid.fit(features_2, y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END .....max_iter=50, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=50, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=50, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .........max_iter=65, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=65, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=65, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ...max_iter=80, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=80, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=80, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=155, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=155, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=155, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=80, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=80, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=80, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=95, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=95, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=95, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .max_iter=155, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=155, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=155, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END .max_iter=125, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=125, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=125, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .....max_iter=65, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=65, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=65, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ..........max_iter=185, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=185, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=185, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .......max_iter=125, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=125, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=125, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .....max_iter=80, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=80, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=80, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .max_iter=170, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=170, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=170, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ....max_iter=110, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=110, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=110, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=110, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=110, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=110, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ..........max_iter=125, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=125, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=125, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ...max_iter=50, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=50, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=50, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ........max_iter=95, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=95, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=95, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ....max_iter=155, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=155, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=155, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=110, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=110, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=110, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ........max_iter=170, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=170, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=170, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .....max_iter=95, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=95, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .....max_iter=95, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=140, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .max_iter=95, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=95, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=95, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END ..max_iter=155, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=155, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=155, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END max_iter=65, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=65, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=65, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END ..max_iter=125, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=125, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=125, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=125, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=125, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=125, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=125, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=50, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=50, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=50, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=95, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=50, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=50, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=50, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=110, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ........max_iter=155, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=155, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=155, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END max_iter=80, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=80, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=80, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END .max_iter=80, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=80, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=80, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=80, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ...max_iter=170, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=170, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=170, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END .........max_iter=140, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=140, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=140, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END max_iter=95, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=95, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=95, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ....max_iter=50, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=50, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=50, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...........max_iter=65, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ...........max_iter=65, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ...........max_iter=65, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=170, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ...max_iter=65, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=65, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ...max_iter=65, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=155, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=110, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=110, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=110, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=95, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=95, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=95, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=110, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=110, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..max_iter=110, multi_class=multinomial, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=155, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=155, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=155, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ..........max_iter=65, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=ovr, solver=saga; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END ........max_iter=125, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END ..max_iter=65, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=65, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END ..max_iter=65, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END max_iter=140, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=140, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=140, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=185, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=185, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=185, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=80, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=80, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=80, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=170, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=170, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=170, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ....max_iter=65, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=65, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=65, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=185, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ....max_iter=140, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=140, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=140, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=170, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END ...max_iter=140, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=140, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=140, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ..........max_iter=110, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=110, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ..........max_iter=110, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ....max_iter=185, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=185, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=185, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=155, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END ....max_iter=170, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=170, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=170, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=185, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=185, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END ...max_iter=185, multi_class=auto, solver=newton-cg; total time=   0.0s
# [CV] END .......max_iter=140, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=140, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=140, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=65, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=65, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=65, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ...........max_iter=50, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ...........max_iter=50, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ...........max_iter=50, multi_class=ovr, solver=sag; total time=   0.0s
# [CV] END ........max_iter=50, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=50, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=50, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END ....max_iter=125, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=125, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ....max_iter=125, multi_class=ovr, solver=newton-cg; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=185, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=155, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=155, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=155, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=125, multi_class=auto, solver=sag; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=80, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END ........max_iter=110, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END max_iter=110, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=110, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END max_iter=110, multi_class=multinomial, solver=newton-cg; total time=   0.0s
# [CV] END .......max_iter=185, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=185, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .......max_iter=185, multi_class=auto, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=65, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=65, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .max_iter=65, multi_class=multinomial, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=50, multi_class=ovr, solver=lbfgs; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .........max_iter=95, multi_class=auto, solver=saga; total time=   0.0s
# [CV] END .max_iter=140, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=140, multi_class=multinomial, solver=saga; total time=   0.0s
# [CV] END .max_iter=140, multi_class=multinomial, solver=saga; total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_48/258951960.py in <module>
# ----> 1 grid.fit(features_2, y)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %% [markdown]
# Источник для дальнейшей категоризации

# %% [markdown]
# https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f

# %% [markdown]
# Модели полюс нейронка, узнать про написание своего ансамбля
# https://www.kaggle.com/code/abhishek/approaching-almost-any-nlp-problem-on-kaggle/notebook

# %% [markdown]
# Что дальше?
#
# Всё же продолжить работу с тысячей строк. Опробовать модели через пайплайн
